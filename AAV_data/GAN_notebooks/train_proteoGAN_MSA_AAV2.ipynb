# %%
import torch
from torch.utils.tensorboard import SummaryWriter
import torch.optim as optim
TB_writer = SummaryWriter()
from GAN_model.resnetGAN import *
from GAN_model.ProteoGAN import *
from utils.dataloader import *
from utils.torch_utils import *
from utils.metrics import *

# %%
args_run_name = 'ProteoGAN_AAV_MSA'
# args; TODO: move these to parser for script
args_batch_size=64; args_seed=42; args_eval_n_seq = 500
args_epoch = 300
# GAN specific param
args_z_dim = 128; args_dim = 256
# optimizer specific param
args_lr_Gen = 1e-4; args_lr_Disc = 8e-5; args_loss = 'hinge'
# train discriminator more initially
# according to https://livebook.manning.com/book/gans-in-action/chapter-5/185
args_disc_iters_init = 2; args_disc_iters = 1; args_disc_iters_init_epoch = 50
# make dir
os.makedirs('checkpoints/'+args_run_name, exist_ok=True)
os.makedirs('out/'+args_run_name+'/plot_out/', exist_ok=True)
os.makedirs('out/'+args_run_name+'/seq_out/', exist_ok=True)

# %%
seed_everything(args_seed)
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
# keep dataset in cpu
MSA_data = MSA_dataset('AAV_data/AAV_target_MSA.fasta', 
    torch.device('cpu'), pseudo_MSA=False)
# Out:
# 100%|██████████| 466/466 [00:00<00:00, 7832.03it/s]

# %% [markdown]
# ### Creating data sets

# %%
# creating data set with train/val split
train_len = int(MSA_data.length*0.85-MSA_data.length)
val_len = MSA_data.length - train_len
train_data, val_data = torch.utils.data.random_split(
    MSA_data, [train_len, val_len], 
    generator=torch.Generator().manual_seed(args_seed))
# decoding train and validation sequences for evaluation
val_seqs = [decode_one_seq(torch.argmax(data, dim=-1).detach().cpu()) 
            for data in val_data]
tr_seqs = [decode_one_seq(torch.argmax(data, dim=-1).detach().cpu()) 
           for data in train_data]
# creating dataloader for training data
loader = torch.utils.data.DataLoader(
    train_data, batch_size=args_batch_size, shuffle=True,
    num_workers=1, pin_memory=True)
# fixed parameters
n_chars = 21; seq_len = len(val_seqs[0])

# %% [markdown]
# ### Evaluating positive and negative control sequences to obtain baseline metrics
# Positive: sample of real sequences and simulates a perfect model
#
# Negative: a sample that simulates the worst possible model for each metric: \
#     (constant sequence for MMD, repeated sequences for diversity measures).

# %%
pos_ctrl_seqs = np.random.choice(tr_seqs, size=len(val_seqs), replace=False)
# constant sequences for MMD
neg_ctrl_seqs_MMD = []
for _ in range(len(val_seqs)):
    rand_aa_idx = np.random.randint(0, high=19)
    rand_seq = decode_one_seq(
        np.random.randint(rand_aa_idx, high=rand_aa_idx+2, size=seq_len))
    neg_ctrl_seqs_MMD.append(rand_seq)
# repeated sequences for diversity measures
rand_seq = decode_one_seq(np.random.randint(0, high=21, size=seq_len))
neg_ctrl_seqs_diversity = [rand_seq for _ in range(len(val_seqs))]
# report baseline
MMD_pos = mmd(seq1=pos_ctrl_seqs, seq2=val_seqs)
MMD_neg = mmd(seq1=neg_ctrl_seqs_MMD, seq2=val_seqs)
Entropy_pos = abs(entropy(seq1=pos_ctrl_seqs, seq2=val_seqs))
Entropy_neg = abs(entropy(seq1=neg_ctrl_seqs_diversity, seq2=val_seqs))
Distance_pos = abs(distance(seq1=pos_ctrl_seqs, seq2=val_seqs))
Distance_neg = abs(distance(seq1=neg_ctrl_seqs_diversity, seq2=val_seqs))
Pearson_cor_pos = pearson_cor(seq1=pos_ctrl_seqs, seq2=val_seqs, random_n=1000)[1].item()

# %%
## Pearson corr higher the better, all other lower the better
print('>>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr' )
print(f'>>> For postivie control:\n'
      f'{MMD_pos:.5} , {Entropy_pos:.5} , {Distance_pos:.5} , {Pearson_cor_pos:.5}')
print(f'>>> For negative control:\n'
      f'{MMD_neg:.5} , {Entropy_neg:.5} , {Distance_neg:.5} , 0.000')
# Out:
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# >>> For postivie control:
# 0.2118 , 0.0017741 , 0.10012 , 0.95812
# >>> For negative control:
# 0.33255 , 0.018137 , 1.9 , 0.000

# %%
def save_checkpoints(discriminator, generator, optim_D, optim_G,  
               scheduler_D, scheduler_G, epoch):
    torch.save({
        'epoch': epoch,
        'disc_state_dict': discriminator.state_dict(),
        'gen_state_dict': generator.state_dict(),
        'optim_D_state_dict': optim_D.state_dict(),
        'optim_G_state_dict': optim_G.state_dict(),
        'scheduler_D_state_dict': scheduler_D.state_dict(),
        'scheduler_G_state_dict': scheduler_G.state_dict(),
    }, os.path.join('checkpoints/'+args_run_name, 'epoch_{}'.format(epoch)))
    return

def load_checkpoints(discriminator, generator, optim_D, optim_G,
                     scheduler_D, scheduler_G, epoch):
    checkpoints = torch.load(
        os.path.join('checkpoints'+args_run_name, 'epoch_{}'.format(epoch)))  
    discriminator.load_state_dict(checkpoints['disc_state_dict'])
    generator.load_state_dict(checkpoints['gen_state_dict'])
    optim_D.load_state_dict(checkpoints['optim_D_state_dict'])
    optim_G.load_state_dict(checkpoints['optim_G_state_dict'])
    scheduler_D.load_state_dict(checkpoints['scheduler_D_state_dict'])
    scheduler_G.load_state_dict(checkpoints['scheduler_G_state_dict'])
    return

# %% [markdown]
# ## Init model

# %%
# init model and optimizer

Disc = Discriminator(args_dim, seq_len=seq_len, n_chars=n_chars).to(device)
Gen = Generator(args_dim, seq_len=seq_len, n_chars=n_chars, 
                z_dim=args_z_dim).to(device)

# Disc = ResNetSN_Discriminator(args_dim, seq_len, n_chars).to(device)
# Gen = ResNetSN_Generator(args_dim, seq_len, n_chars, args_z_dim).to(device)

optim_disc = optim.Adam(filter(lambda p: p.requires_grad, Disc.parameters()),
                        lr=args_lr_Disc, betas=(0.0, 0.9))
optim_gen = optim.Adam(Gen.parameters(), lr=args_lr_Gen, betas=(0.0, 0.9))
# use an exponentially decaying learning rate
scheduler_d = optim.lr_scheduler.ExponentialLR(optim_disc, gamma=0.99)
scheduler_g = optim.lr_scheduler.ExponentialLR(optim_gen, gamma=0.99)

#load_checkpoints(Disc, Gen, optim_disc, optim_gen, scheduler_d, scheduler_g, 0)
#save_checkpoints(Disc, Gen, optim_disc, optim_gen, scheduler_d, scheduler_g, 0)

# %%
def sample_generated(generator, epoch, run_name, n_seq=500):
    # random sampling n_seq noise, batched 100 noise at a time
    # return sampled n_seq sequences, also saving them to fasta file
    gen_seqs = []
    max_batch_size = 100
    for _ in range(n_seq//max_batch_size):
        z = torch.randn(max_batch_size, args_z_dim, device=device)
        gen_probs = generator(z)
        batched_seq = [decode_one_seq(
            gen_prob.argmax(-1).cpu().numpy()) for gen_prob in gen_probs]
        gen_seqs += batched_seq
        torch.cuda.empty_cache()
    # saving seqs in fasta
    fasta_name = 'out/' + run_name + '/seq_out/epoch_' + str(epoch) + '.fasta'
    outfile = open(fasta_name, 'w')
    for i, seq in enumerate(gen_seqs):
        seq_id = 'Epoch'+str(epoch)+'_seq'+str(i)
        outfile.write('>' + seq_id + '\n')
        outfile.write(seq + '\n')
    return gen_seqs


def write_eval_TB(writer, MMD, Entropy, Distance, Pearson, epoch):
    writer.add_scalar(args_run_name+'/MMD',  MMD, epoch)
    writer.add_scalar(args_run_name+'/abs(D_Entropy)', Entropy, epoch)
    writer.add_scalar(args_run_name+'/abs(D_Distance)', Distance, epoch)
    writer.add_scalar(args_run_name+'/Pearson Correlation', Pearson, epoch)
    return

def evaluate(epoch):
    # eval mode
    Gen.eval()
    # sample args_eval_n_seq sequences
    gen_seqs = sample_generated(Gen, epoch, args_run_name, n_seq=args_eval_n_seq)
    MMD = mmd(seq1=gen_seqs, seq2=val_seqs)
    Entropy = abs(entropy(seq1=gen_seqs, seq2=val_seqs))
    Distance = abs(distance(seq1=gen_seqs, seq2=val_seqs))
    Pearson = pearson_cor(
        seq1=gen_seqs, seq2=val_seqs, random_n=args_eval_n_seq)[1].item()
    print(f'#========== evaluating for epoch ' f'{epoch} ' f'==========#')
    print('>>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr \n'
          f'{MMD:.5} , {Entropy:.5} , {Distance:.5} , {Pearson:.5}')
    # save the gap distribution plot
    plot_gap_dist(seqs=gen_seqs, run_name=args_run_name, epoch=epoch)
    write_eval_TB(TB_writer, MMD, Entropy, Distance, Pearson, epoch)
    # revert to train mode
    Gen.train()
    return

# %%
def train(epoch):
    for batch_idx, data in enumerate(loader):
        if data.size()[0] != args_batch_size:
            continue
        else:
            data = data.to(device)
        # train discriminator more initially
        if epoch <= args_disc_iters_init_epoch: 
            disc_iters = args_disc_iters_init
        else:
            disc_iters = args_disc_iters
        # update discriminator
        for _ in range(disc_iters):
            z = torch.randn(args_batch_size, args_z_dim, device=device)
            optim_disc.zero_grad()
            optim_gen.zero_grad()
            real_D = Disc(data)
            fake_D = Disc(Gen(z))
            if args_loss == 'hinge':
                disc_loss = nn.ReLU()(1.0 - real_D).mean() + \
                nn.ReLU()(1.0 + fake_D).mean()
            disc_loss.backward()
            optim_disc.step()
        # record output for both fake and real from discriminator
        real_prob_avg = real_D.mean()
        fake_prob_avg = fake_D.mean()
        
        # update generator
        z = torch.randn(args_batch_size, args_z_dim, device=device)
        optim_disc.zero_grad()
        optim_gen.zero_grad()
        if args_loss == 'hinge' or args_loss == 'wasserstein':
            gen_loss = -Disc(Gen(z)).mean()
        gen_loss.backward()
        optim_gen.step()
        
        # write to Tensor board
        iter = len(loader)*epoch + batch_idx
        TB_writer.add_scalars(
            args_run_name+'/GAN loss', {
            'Disc_loss': disc_loss,
            'Gen_loss': gen_loss,
        }, iter)
        TB_writer.add_scalars(
            args_run_name+'/Discriminator out', {
            'Real prob': real_prob_avg,
            'Fake prob': fake_prob_avg,
        }, iter)
        if batch_idx % 60 == 0:
            print('disc loss', disc_loss.item(), 'gen loss', gen_loss.item())
    # update lr scheduler
    scheduler_d.step()
    scheduler_g.step()
    return

# %%
for epoch in range(args_epoch):
    train(epoch)
    save_checkpoints(Disc, Gen, optim_disc, optim_gen, 
                     scheduler_d, scheduler_g, epoch)
    if epoch != 0:
        os.remove(os.path.join('checkpoints/'+args_run_name, 
                               'epoch_{}'.format(epoch-1)))
    # eval every 2 epoch
    if epoch % 2 == 0:
        evaluate(epoch)
# Out:
# disc loss 1.9991246461868286 gen loss -0.054017454385757446
# #========== evaluating for epoch 0 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22209 , 0.008184 , 0.090369 , 0.93752
# # ================== Sampling 500 sequences at epoch 0 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.9679758548736572 gen loss -0.05976656824350357
# disc loss 1.9316887855529785 gen loss -0.0715143159031868
# #========== evaluating for epoch 2 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22273 , 0.0081778 , 0.090379 , 0.93789
# # ================== Sampling 500 sequences at epoch 2 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.890212059020996 gen loss -0.08376333862543106
# disc loss 1.8348057270050049 gen loss -0.10136439651250839
# #========== evaluating for epoch 4 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22191 , 0.0081911 , 0.090432 , 0.94154
# # ================== Sampling 500 sequences at epoch 4 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.8080930709838867 gen loss -0.11484336853027344
# disc loss 1.7638585567474365 gen loss -0.13120988011360168
# #========== evaluating for epoch 6 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22165 , 0.008177 , 0.090413 , 0.94089
# # ================== Sampling 500 sequences at epoch 6 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7015070915222168 gen loss -0.15087328851222992
# disc loss 1.669682264328003 gen loss -0.15546420216560364
# #========== evaluating for epoch 8 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22078 , 0.0081412 , 0.090367 , 0.93968
# # ================== Sampling 500 sequences at epoch 8 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5629210472106934 gen loss -0.14633794128894806
# disc loss 1.6162750720977783 gen loss -0.1338994950056076
# #========== evaluating for epoch 10 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22112 , 0.0082178 , 0.090382 , 0.93767
# # ================== Sampling 500 sequences at epoch 10 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5507879257202148 gen loss -0.0992748811841011
# disc loss 1.5372424125671387 gen loss -0.053960151970386505
# #========== evaluating for epoch 12 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22001 , 0.0081137 , 0.0902 , 0.94405
# # ================== Sampling 500 sequences at epoch 12 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.506790280342102 gen loss -0.011982517316937447
# disc loss 1.5249298810958862 gen loss 0.020047949627041817
# #========== evaluating for epoch 14 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22023 , 0.0080493 , 0.090117 , 0.94718
# # ================== Sampling 500 sequences at epoch 14 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.4558966159820557 gen loss 0.07978174090385437
# disc loss 1.38059663772583 gen loss 0.12707383930683136
# #========== evaluating for epoch 16 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21983 , 0.0080412 , 0.089898 , 0.94476
# # ================== Sampling 500 sequences at epoch 16 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.389611840248108 gen loss 0.15997561812400818
# disc loss 1.4392249584197998 gen loss 0.14235471189022064
# #========== evaluating for epoch 18 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21811 , 0.0080445 , 0.08977 , 0.94925
# # ================== Sampling 500 sequences at epoch 18 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3675639629364014 gen loss 0.23329710960388184
# disc loss 1.3939157724380493 gen loss 0.2263280749320984
# #========== evaluating for epoch 20 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21653 , 0.008023 , 0.089394 , 0.94996
# # ================== Sampling 500 sequences at epoch 20 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3416541814804077 gen loss 0.28797072172164917
# disc loss 1.357093334197998 gen loss 0.2893296480178833
# #========== evaluating for epoch 22 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21624 , 0.0077809 , 0.088737 , 0.9527
# # ================== Sampling 500 sequences at epoch 22 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3282599449157715 gen loss 0.35242146253585815
# disc loss 1.4300315380096436 gen loss 0.34116214513778687
# #========== evaluating for epoch 24 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21455 , 0.0076662 , 0.08762 , 0.958
# # ================== Sampling 500 sequences at epoch 24 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3895697593688965 gen loss 0.3620556592941284
# disc loss 1.2476303577423096 gen loss 0.4001465439796448
# #========== evaluating for epoch 26 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21422 , 0.007493 , 0.087293 , 0.95383
# # ================== Sampling 500 sequences at epoch 26 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3274450302124023 gen loss 0.4059767723083496
# disc loss 1.293637752532959 gen loss 0.5075451135635376
# #========== evaluating for epoch 28 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21396 , 0.0074303 , 0.085816 , 0.96265
# # ================== Sampling 500 sequences at epoch 28 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2618308067321777 gen loss 0.4638606905937195
# disc loss 1.2993603944778442 gen loss 0.48085445165634155
# #========== evaluating for epoch 30 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21223 , 0.0070891 , 0.082448 , 0.96081
# # ================== Sampling 500 sequences at epoch 30 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2571525573730469 gen loss 0.5213378667831421
# disc loss 1.3110164403915405 gen loss 0.5090201497077942
# #========== evaluating for epoch 32 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21175 , 0.0068233 , 0.080124 , 0.9531
# # ================== Sampling 500 sequences at epoch 32 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.45450758934021 gen loss 0.5103275775909424
# disc loss 1.3959505558013916 gen loss 0.4989013075828552
# #========== evaluating for epoch 34 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21304 , 0.0066628 , 0.076653 , 0.95711
# # ================== Sampling 500 sequences at epoch 34 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.461482048034668 gen loss 0.5569322109222412
# disc loss 1.4321377277374268 gen loss 0.5379379987716675
# #========== evaluating for epoch 36 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21388 , 0.0064522 , 0.072678 , 0.94003
# # ================== Sampling 500 sequences at epoch 36 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.4113373756408691 gen loss 0.52312171459198
# disc loss 1.5663962364196777 gen loss 0.5773189067840576
# #========== evaluating for epoch 38 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2169 , 0.0058619 , 0.064966 , 0.93164
# # ================== Sampling 500 sequences at epoch 38 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.438745141029358 gen loss 0.5855380296707153
# disc loss 1.4929699897766113 gen loss 0.613004207611084
# #========== evaluating for epoch 40 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.21916 , 0.0058082 , 0.059059 , 0.93729
# # ================== Sampling 500 sequences at epoch 40 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6314189434051514 gen loss 0.6252936124801636
# disc loss 1.5478687286376953 gen loss 0.6669509410858154
# #========== evaluating for epoch 42 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22161 , 0.0056197 , 0.056042 , 0.92579
# # ================== Sampling 500 sequences at epoch 42 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.571263074874878 gen loss 0.6462162137031555
# disc loss 1.4421029090881348 gen loss 0.6558980941772461
# #========== evaluating for epoch 44 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.22132 , 0.0052128 , 0.052588 , 0.91338
# # ================== Sampling 500 sequences at epoch 44 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.529900312423706 gen loss 0.6135865449905396
# disc loss 1.4166847467422485 gen loss 0.6353282928466797
# #========== evaluating for epoch 46 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2288 , 0.0049081 , 0.040823 , 0.91113
# # ================== Sampling 500 sequences at epoch 46 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5069727897644043 gen loss 0.6764628887176514
# disc loss 1.4858481884002686 gen loss 0.6726562976837158
# #========== evaluating for epoch 48 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.23017 , 0.0047751 , 0.039242 , 0.91827
# # ================== Sampling 500 sequences at epoch 48 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.530200481414795 gen loss 0.6961802244186401
# disc loss 1.4901509284973145 gen loss 0.7202483415603638
# #========== evaluating for epoch 50 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.23117 , 0.0046647 , 0.039444 , 0.92389
# # ================== Sampling 500 sequences at epoch 50 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.509136438369751 gen loss 0.6769644618034363
# disc loss 1.510312795639038 gen loss 0.7278348207473755
# #========== evaluating for epoch 52 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.23788 , 0.0045367 , 0.029673 , 0.90311
# # ================== Sampling 500 sequences at epoch 52 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.41178560256958 gen loss 0.6862475872039795
# disc loss 1.4078946113586426 gen loss 0.6467338800430298
# #========== evaluating for epoch 54 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24398 , 0.0043497 , 0.020692 , 0.89467
# # ================== Sampling 500 sequences at epoch 54 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6477248668670654 gen loss 0.6796850562095642
# disc loss 1.4484364986419678 gen loss 0.6898095607757568
# #========== evaluating for epoch 56 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24058 , 0.0040154 , 0.021015 , 0.87939
# # ================== Sampling 500 sequences at epoch 56 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5904409885406494 gen loss 0.6567943096160889
# disc loss 1.4526158571243286 gen loss 0.6200918555259705
# #========== evaluating for epoch 58 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24512 , 0.0035056 , 0.013815 , 0.88518
# # ================== Sampling 500 sequences at epoch 58 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5743216276168823 gen loss 0.577816903591156
# disc loss 1.4983750581741333 gen loss 0.5770684480667114
# #========== evaluating for epoch 60 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2484 , 0.0036173 , 0.010899 , 0.89812
# # ================== Sampling 500 sequences at epoch 60 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.540745496749878 gen loss 0.5342351198196411
# disc loss 1.5564732551574707 gen loss 0.5435454845428467
# #========== evaluating for epoch 62 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24587 , 0.0037109 , 0.01145 , 0.87108
# # ================== Sampling 500 sequences at epoch 62 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.705357551574707 gen loss 0.49439743161201477
# disc loss 1.6253454685211182 gen loss 0.4804297685623169
# #========== evaluating for epoch 64 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24337 , 0.0032823 , 0.01257 , 0.8708
# # ================== Sampling 500 sequences at epoch 64 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6296550035476685 gen loss 0.5249887108802795
# disc loss 1.7037217617034912 gen loss 0.4514423906803131
# #========== evaluating for epoch 66 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24845 , 0.0031355 , 0.0051917 , 0.86654
# # ================== Sampling 500 sequences at epoch 66 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7943599224090576 gen loss 0.4798344373703003
# disc loss 1.755635142326355 gen loss 0.4558611214160919
# #========== evaluating for epoch 68 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24872 , 0.0029175 , 0.0016866 , 0.85928
# # ================== Sampling 500 sequences at epoch 68 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7207552194595337 gen loss 0.44832295179367065
# disc loss 1.8757507801055908 gen loss 0.4136275053024292
# #========== evaluating for epoch 70 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24461 , 0.0029045 , 0.0036829 , 0.87065
# # ================== Sampling 500 sequences at epoch 70 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7487236261367798 gen loss 0.4237574636936188
# disc loss 1.6932164430618286 gen loss 0.4026701748371124
# #========== evaluating for epoch 72 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.23727 , 0.0028089 , 0.0078695 , 0.84285
# # ================== Sampling 500 sequences at epoch 72 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7527382373809814 gen loss 0.37383824586868286
# disc loss 1.7216376066207886 gen loss 0.3742271959781647
# #========== evaluating for epoch 74 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24291 , 0.0025859 , 0.0038192 , 0.87707
# # ================== Sampling 500 sequences at epoch 74 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.699371099472046 gen loss 0.35805830359458923
# disc loss 1.8025166988372803 gen loss 0.3352726399898529
# #========== evaluating for epoch 76 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.23991 , 0.0026037 , 0.0029657 , 0.83964
# # ================== Sampling 500 sequences at epoch 76 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.8494136333465576 gen loss 0.31540393829345703
# disc loss 1.8193672895431519 gen loss 0.3076079189777374
# #========== evaluating for epoch 78 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24069 , 0.0024356 , 0.00744 , 0.84993
# # ================== Sampling 500 sequences at epoch 78 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7999787330627441 gen loss 0.29116132855415344
# disc loss 1.689134120941162 gen loss 0.2793932259082794
# #========== evaluating for epoch 80 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24571 , 0.0022936 , 0.017424 , 0.85091
# # ================== Sampling 500 sequences at epoch 80 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7749922275543213 gen loss 0.32152092456817627
# disc loss 1.775315761566162 gen loss 0.3119661808013916
# #========== evaluating for epoch 82 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24807 , 0.0021376 , 0.019572 , 0.84435
# # ================== Sampling 500 sequences at epoch 82 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7399743795394897 gen loss 0.2774035334587097
# disc loss 1.6757638454437256 gen loss 0.23751895129680634
# #========== evaluating for epoch 84 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24424 , 0.0020545 , 0.010814 , 0.84243
# # ================== Sampling 500 sequences at epoch 84 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6195061206817627 gen loss 0.2767687737941742
# disc loss 1.7698974609375 gen loss 0.26465851068496704
# #========== evaluating for epoch 86 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.25827 , 0.0017694 , 0.034433 , 0.82976
# # ================== Sampling 500 sequences at epoch 86 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7851834297180176 gen loss 0.25925493240356445
# disc loss 1.9037210941314697 gen loss 0.24879255890846252
# #========== evaluating for epoch 88 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.24733 , 0.0019742 , 0.019807 , 0.8171
# # ================== Sampling 500 sequences at epoch 88 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6941249370574951 gen loss 0.2805972099304199
# disc loss 1.8535759449005127 gen loss 0.2770348787307739
# #========== evaluating for epoch 90 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.25054 , 0.0017658 , 0.027686 , 0.8031
# # ================== Sampling 500 sequences at epoch 90 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.8569717407226562 gen loss 0.2831233739852905
# disc loss 1.7610142230987549 gen loss 0.2260149121284485
# #========== evaluating for epoch 92 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.25354 , 0.0016379 , 0.028811 , 0.79935
# # ================== Sampling 500 sequences at epoch 92 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7103374004364014 gen loss 0.25924360752105713
# disc loss 1.815395712852478 gen loss 0.23936113715171814
# #========== evaluating for epoch 94 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.25615 , 0.0016456 , 0.034096 , 0.80086
# # ================== Sampling 500 sequences at epoch 94 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.8586400747299194 gen loss 0.2021794468164444
# disc loss 1.706892967224121 gen loss 0.2692270576953888
# #========== evaluating for epoch 96 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26273 , 0.0014429 , 0.042737 , 0.79575
# # ================== Sampling 500 sequences at epoch 96 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.836163878440857 gen loss 0.20648443698883057
# disc loss 1.7388725280761719 gen loss 0.20505934953689575
# #========== evaluating for epoch 98 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26153 , 0.0015032 , 0.03969 , 0.80938
# # ================== Sampling 500 sequences at epoch 98 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7437975406646729 gen loss 0.2095727026462555
# disc loss 1.8402401208877563 gen loss 0.2362629771232605
# #========== evaluating for epoch 100 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26176 , 0.0014213 , 0.040345 , 0.78724
# # ================== Sampling 500 sequences at epoch 100 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7811295986175537 gen loss 0.23219960927963257
# disc loss 1.7639451026916504 gen loss 0.25908148288726807
# #========== evaluating for epoch 102 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.25973 , 0.0013774 , 0.039751 , 0.80264
# # ================== Sampling 500 sequences at epoch 102 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7855430841445923 gen loss 0.23129060864448547
# disc loss 1.7793909311294556 gen loss 0.2381024956703186
# #========== evaluating for epoch 104 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2609 , 0.0014458 , 0.037488 , 0.80264
# # ================== Sampling 500 sequences at epoch 104 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7821784019470215 gen loss 0.22491425275802612
# disc loss 1.7819057703018188 gen loss 0.2172224521636963
# #========== evaluating for epoch 106 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27252 , 0.00098717 , 0.047994 , 0.79468
# # ================== Sampling 500 sequences at epoch 106 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.8092074394226074 gen loss 0.2205560803413391
# disc loss 1.8045809268951416 gen loss 0.20044244825839996
# #========== evaluating for epoch 108 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26977 , 0.0014893 , 0.044277 , 0.76582
# # ================== Sampling 500 sequences at epoch 108 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7140767574310303 gen loss 0.21118193864822388
# disc loss 1.7695112228393555 gen loss 0.20729348063468933
# #========== evaluating for epoch 110 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27014 , 0.0011835 , 0.039468 , 0.79277
# # ================== Sampling 500 sequences at epoch 110 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.751942753791809 gen loss 0.19630131125450134
# disc loss 1.7270002365112305 gen loss 0.22348184883594513
# #========== evaluating for epoch 112 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2669 , 0.0014251 , 0.031162 , 0.78636
# # ================== Sampling 500 sequences at epoch 112 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7492012977600098 gen loss 0.2354748398065567
# disc loss 1.7210290431976318 gen loss 0.2209947556257248
# #========== evaluating for epoch 114 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27209 , 0.0012494 , 0.039758 , 0.7997
# # ================== Sampling 500 sequences at epoch 114 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7622159719467163 gen loss 0.2535746693611145
# disc loss 1.716081976890564 gen loss 0.2500026226043701
# #========== evaluating for epoch 116 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27174 , 0.0011936 , 0.033304 , 0.7834
# # ================== Sampling 500 sequences at epoch 116 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7510719299316406 gen loss 0.2062864452600479
# disc loss 1.7500793933868408 gen loss 0.24794146418571472
# #========== evaluating for epoch 118 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26961 , 0.0012897 , 0.029529 , 0.79013
# # ================== Sampling 500 sequences at epoch 118 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7367855310440063 gen loss 0.22667628526687622
# disc loss 1.7270381450653076 gen loss 0.220683753490448
# #========== evaluating for epoch 120 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26795 , 0.0014034 , 0.024094 , 0.77836
# # ================== Sampling 500 sequences at epoch 120 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.715958595275879 gen loss 0.21589970588684082
# disc loss 1.763312578201294 gen loss 0.24177256226539612
# #========== evaluating for epoch 122 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26398 , 0.001398 , 0.014271 , 0.79718
# # ================== Sampling 500 sequences at epoch 122 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.761764407157898 gen loss 0.27251318097114563
# disc loss 1.713447093963623 gen loss 0.25062626600265503
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# #========== evaluating for epoch 124 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26815 , 0.0012224 , 0.023949 , nan
# # ================== Sampling 500 sequences at epoch 124 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6989924907684326 gen loss 0.25580134987831116
# disc loss 1.7221341133117676 gen loss 0.2547169327735901
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# #========== evaluating for epoch 126 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27534 , 0.0011185 , 0.024047 , nan
# # ================== Sampling 500 sequences at epoch 126 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7391870021820068 gen loss 0.28230565786361694
# disc loss 1.7309980392456055 gen loss 0.2904701232910156
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# #========== evaluating for epoch 128 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27379 , 0.0013533 , 0.020629 , nan
# # ================== Sampling 500 sequences at epoch 128 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7155722379684448 gen loss 0.2812163233757019
# disc loss 1.7795085906982422 gen loss 0.25814318656921387
# #========== evaluating for epoch 130 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27382 , 0.001424 , 0.021772 , 0.78331
# # ================== Sampling 500 sequences at epoch 130 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6974475383758545 gen loss 0.24623362720012665
# disc loss 1.6808074712753296 gen loss 0.257803350687027
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# #========== evaluating for epoch 132 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26945 , 0.0014446 , 0.010417 , nan
# # ================== Sampling 500 sequences at epoch 132 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.726703405380249 gen loss 0.2630341649055481
# disc loss 1.7036428451538086 gen loss 0.279459148645401
# #========== evaluating for epoch 134 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27245 , 0.0013835 , 0.015444 , 0.79188
# # ================== Sampling 500 sequences at epoch 134 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.669114112854004 gen loss 0.27078232169151306
# disc loss 1.7303396463394165 gen loss 0.23327898979187012
# #========== evaluating for epoch 136 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2665 , 0.0016907 , 0.0045451 , 0.81572
# # ================== Sampling 500 sequences at epoch 136 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7436842918395996 gen loss 0.22369948029518127
# disc loss 1.6588973999023438 gen loss 0.259907603263855
# #========== evaluating for epoch 138 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26643 , 0.0015044 , 0.0042177 , 0.7634
# # ================== Sampling 500 sequences at epoch 138 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7019875049591064 gen loss 0.25303882360458374
# disc loss 1.6443947553634644 gen loss 0.2213784158229828
# #========== evaluating for epoch 140 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26546 , 0.0017103 , 0.00014925 , 0.80057
# # ================== Sampling 500 sequences at epoch 140 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6753668785095215 gen loss 0.2587398290634155
# disc loss 1.7035388946533203 gen loss 0.27512064576148987
# #========== evaluating for epoch 142 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26941 , 0.0016738 , 0.00073898 , 0.79524
# # ================== Sampling 500 sequences at epoch 142 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.677898645401001 gen loss 0.2496555596590042
# disc loss 1.7049071788787842 gen loss 0.2225339412689209
# #========== evaluating for epoch 144 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26495 , 0.0017577 , 0.0028989 , 0.80818
# # ================== Sampling 500 sequences at epoch 144 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.665299654006958 gen loss 0.2455173134803772
# disc loss 1.67915678024292 gen loss 0.2349141538143158
# #========== evaluating for epoch 146 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27316 , 0.0016343 , 0.0015837 , 0.78411
# # ================== Sampling 500 sequences at epoch 146 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.7113323211669922 gen loss 0.22959846258163452
# disc loss 1.6932690143585205 gen loss 0.21929383277893066
# #========== evaluating for epoch 148 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26727 , 0.0016549 , 0.0060222 , 0.79125
# # ================== Sampling 500 sequences at epoch 148 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6553553342819214 gen loss 0.2549291253089905
# disc loss 1.693669080734253 gen loss 0.23244647681713104
# #========== evaluating for epoch 150 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26372 , 0.0018156 , 0.0072306 , 0.81007
# # ================== Sampling 500 sequences at epoch 150 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6942821741104126 gen loss 0.2252817451953888
# disc loss 1.6801468133926392 gen loss 0.2258874773979187
# #========== evaluating for epoch 152 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26635 , 0.0015189 , 0.0039675 , 0.80498
# # ================== Sampling 500 sequences at epoch 152 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6765515804290771 gen loss 0.2597930431365967
# disc loss 1.6802902221679688 gen loss 0.26395177841186523
# #========== evaluating for epoch 154 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27172 , 0.0014951 , 0.0022522 , 0.783
# # ================== Sampling 500 sequences at epoch 154 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.696563959121704 gen loss 0.25784701108932495
# disc loss 1.6662031412124634 gen loss 0.27692580223083496
# #========== evaluating for epoch 156 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27208 , 0.0016854 , 0.0055734 , 0.7791
# # ================== Sampling 500 sequences at epoch 156 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6660780906677246 gen loss 0.26549071073532104
# disc loss 1.6662076711654663 gen loss 0.23380392789840698
# #========== evaluating for epoch 158 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27178 , 0.0015756 , 0.0045705 , 0.80453
# # ================== Sampling 500 sequences at epoch 158 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6986207962036133 gen loss 0.24138568341732025
# disc loss 1.6388535499572754 gen loss 0.23388957977294922
# #========== evaluating for epoch 160 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.26844 , 0.0016261 , 0.0080185 , 0.78882
# # ================== Sampling 500 sequences at epoch 160 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6764671802520752 gen loss 0.28095871210098267
# disc loss 1.6244946718215942 gen loss 0.24078068137168884
# #========== evaluating for epoch 162 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27252 , 0.0015715 , 0.0040257 , 0.8038
# # ================== Sampling 500 sequences at epoch 162 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6705780029296875 gen loss 0.2527047395706177
# disc loss 1.6647496223449707 gen loss 0.27992039918899536
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\canal\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# #========== evaluating for epoch 164 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27654 , 0.0014598 , 0.00030053 , nan
# # ================== Sampling 500 sequences at epoch 164 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6501352787017822 gen loss 0.26434993743896484
# disc loss 1.6380215883255005 gen loss 0.24868249893188477
# #========== evaluating for epoch 166 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27721 , 0.0016021 , 0.00065517 , 0.80791
# # ================== Sampling 500 sequences at epoch 166 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6448767185211182 gen loss 0.27524012327194214
# disc loss 1.6391286849975586 gen loss 0.2521844208240509
# #========== evaluating for epoch 168 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.27663 , 0.0014562 , 0.00030744 , 0.79639
# # ================== Sampling 500 sequences at epoch 168 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.6067246198654175 gen loss 0.2794768512248993
# disc loss 1.654712438583374 gen loss 0.2775317430496216
# #========== evaluating for epoch 170 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.28575 , 0.0013736 , 0.0081261 , 0.78086
# # ================== Sampling 500 sequences at epoch 170 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5966123342514038 gen loss 0.30198848247528076
# disc loss 1.5966439247131348 gen loss 0.24974849820137024
# #========== evaluating for epoch 172 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.28406 , 0.0015354 , 0.0065951 , 0.78266
# # ================== Sampling 500 sequences at epoch 172 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5909507274627686 gen loss 0.2690708637237549
# disc loss 1.606002688407898 gen loss 0.2627255618572235
# #========== evaluating for epoch 174 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.28276 , 0.0015901 , 0.0055861 , 0.7693
# # ================== Sampling 500 sequences at epoch 174 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5726380348205566 gen loss 0.2721537947654724
# disc loss 1.5937447547912598 gen loss 0.2861144542694092
# #========== evaluating for epoch 176 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.28769 , 0.0014705 , 0.0086451 , 0.77585
# # ================== Sampling 500 sequences at epoch 176 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5676074028015137 gen loss 0.29066771268844604
# disc loss 1.6187496185302734 gen loss 0.27790921926498413
# #========== evaluating for epoch 178 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2897 , 0.0014609 , 0.013808 , 0.78445
# # ================== Sampling 500 sequences at epoch 178 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5919196605682373 gen loss 0.3185218572616577
# disc loss 1.6006900072097778 gen loss 0.2917260229587555
# #========== evaluating for epoch 180 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2978 , 0.0014358 , 0.020056 , 0.78355
# # ================== Sampling 500 sequences at epoch 180 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5219042301177979 gen loss 0.3019086420536041
# disc loss 1.5201793909072876 gen loss 0.29783934354782104
# #========== evaluating for epoch 182 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2951 , 0.0014339 , 0.017112 , 0.78229
# # ================== Sampling 500 sequences at epoch 182 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.499746322631836 gen loss 0.2991831600666046
# disc loss 1.523788332939148 gen loss 0.3262444734573364
# #========== evaluating for epoch 184 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29599 , 0.0013031 , 0.019364 , 0.77582
# # ================== Sampling 500 sequences at epoch 184 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.5007238388061523 gen loss 0.3067915737628937
# disc loss 1.511178731918335 gen loss 0.2979901432991028
# #========== evaluating for epoch 186 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.3006 , 0.0012657 , 0.021804 , 0.78436
# # ================== Sampling 500 sequences at epoch 186 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# ...
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3282225131988525 gen loss 0.4089016318321228
# disc loss 1.3792771100997925 gen loss 0.41404831409454346
# #========== evaluating for epoch 236 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30204 , 0.0016264 , 0.023283 , 0.79087
# # ================== Sampling 500 sequences at epoch 236 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.327143907546997 gen loss 0.4155706465244293
# disc loss 1.2942211627960205 gen loss 0.39700090885162354
# #========== evaluating for epoch 238 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30379 , 0.0017398 , 0.025981 , 0.79767
# # ================== Sampling 500 sequences at epoch 238 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2666101455688477 gen loss 0.43187859654426575
# disc loss 1.3567614555358887 gen loss 0.4211481213569641
# #========== evaluating for epoch 240 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30958 , 0.0016197 , 0.031903 , 0.79681
# # ================== Sampling 500 sequences at epoch 240 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3327138423919678 gen loss 0.4161738455295563
# disc loss 1.3720028400421143 gen loss 0.3937336206436157
# #========== evaluating for epoch 242 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30304 , 0.001851 , 0.024148 , 0.80018
# # ================== Sampling 500 sequences at epoch 242 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2889302968978882 gen loss 0.3959442377090454
# disc loss 1.313463807106018 gen loss 0.4231948256492615
# #========== evaluating for epoch 244 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.31015 , 0.0014058 , 0.034545 , 0.79378
# # ================== Sampling 500 sequences at epoch 244 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2987089157104492 gen loss 0.37870484590530396
# disc loss 1.2924705743789673 gen loss 0.390114963054657
# #========== evaluating for epoch 246 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30777 , 0.0017242 , 0.030692 , 0.79881
# # ================== Sampling 500 sequences at epoch 246 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3061277866363525 gen loss 0.3855745792388916
# disc loss 1.2984552383422852 gen loss 0.39337271451950073
# #========== evaluating for epoch 248 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2998 , 0.0018869 , 0.021278 , 0.81211
# # ================== Sampling 500 sequences at epoch 248 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.27431321144104 gen loss 0.3487147092819214
# disc loss 1.301621675491333 gen loss 0.37123143672943115
# #========== evaluating for epoch 250 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30673 , 0.0015911 , 0.028645 , 0.81081
# # ================== Sampling 500 sequences at epoch 250 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3033735752105713 gen loss 0.41185176372528076
# disc loss 1.3000988960266113 gen loss 0.4132322072982788
# #========== evaluating for epoch 252 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30797 , 0.0016653 , 0.030899 , 0.80081
# # ================== Sampling 500 sequences at epoch 252 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.294817566871643 gen loss 0.367270827293396
# disc loss 1.2495839595794678 gen loss 0.40720316767692566
# #========== evaluating for epoch 254 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.3036 , 0.0017965 , 0.024442 , 0.80555
# # ================== Sampling 500 sequences at epoch 254 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.334012746810913 gen loss 0.39870190620422363
# disc loss 1.295591115951538 gen loss 0.400394082069397
# #========== evaluating for epoch 256 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30251 , 0.001918 , 0.025949 , 0.80989
# # ================== Sampling 500 sequences at epoch 256 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3168820142745972 gen loss 0.40505605936050415
# disc loss 1.2877461910247803 gen loss 0.3957422971725464
# #========== evaluating for epoch 258 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30297 , 0.0017426 , 0.025199 , 0.78966
# # ================== Sampling 500 sequences at epoch 258 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2422993183135986 gen loss 0.3806394338607788
# disc loss 1.2970337867736816 gen loss 0.3767489492893219
# #========== evaluating for epoch 260 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29841 , 0.0019067 , 0.021504 , 0.80132
# # ================== Sampling 500 sequences at epoch 260 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2980232238769531 gen loss 0.41729575395584106
# disc loss 1.30918288230896 gen loss 0.3735029101371765
# #========== evaluating for epoch 262 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.30148 , 0.0021066 , 0.025006 , 0.80088
# # ================== Sampling 500 sequences at epoch 262 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3351162672042847 gen loss 0.4346126914024353
# disc loss 1.2415907382965088 gen loss 0.4033578932285309
# #========== evaluating for epoch 264 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2991 , 0.0020789 , 0.021177 , 0.81291
# # ================== Sampling 500 sequences at epoch 264 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.271758794784546 gen loss 0.41492700576782227
# disc loss 1.2950849533081055 gen loss 0.41052892804145813
# #========== evaluating for epoch 266 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29951 , 0.0018752 , 0.022326 , 0.80482
# # ================== Sampling 500 sequences at epoch 266 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3175575733184814 gen loss 0.4401209056377411
# disc loss 1.308924674987793 gen loss 0.41896378993988037
# #========== evaluating for epoch 268 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29791 , 0.0020549 , 0.018453 , 0.83032
# # ================== Sampling 500 sequences at epoch 268 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.291640281677246 gen loss 0.3901909291744232
# disc loss 1.256129264831543 gen loss 0.38065624237060547
# #========== evaluating for epoch 270 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.3001 , 0.001623 , 0.024166 , 0.8016
# # ================== Sampling 500 sequences at epoch 270 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.336122751235962 gen loss 0.43470099568367004
# disc loss 1.3350505828857422 gen loss 0.4653436243534088
# #========== evaluating for epoch 272 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29759 , 0.0018285 , 0.018934 , 0.81186
# # ================== Sampling 500 sequences at epoch 272 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2511608600616455 gen loss 0.3924340009689331
# disc loss 1.2437663078308105 gen loss 0.4154264032840729
# #========== evaluating for epoch 274 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29232 , 0.0022431 , 0.012436 , 0.82281
# # ================== Sampling 500 sequences at epoch 274 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.325690507888794 gen loss 0.3986966013908386
# disc loss 1.2547414302825928 gen loss 0.4042049050331116
# #========== evaluating for epoch 276 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29379 , 0.0019607 , 0.015623 , 0.82289
# # ================== Sampling 500 sequences at epoch 276 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.31458580493927 gen loss 0.4118621349334717
# disc loss 1.278270959854126 gen loss 0.3915025293827057
# #========== evaluating for epoch 278 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29888 , 0.0017103 , 0.021611 , 0.81098
# # ================== Sampling 500 sequences at epoch 278 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3094462156295776 gen loss 0.4072096049785614
# disc loss 1.231273889541626 gen loss 0.3667256534099579
# #========== evaluating for epoch 280 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29658 , 0.0018005 , 0.017551 , 0.81576
# # ================== Sampling 500 sequences at epoch 280 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2563557624816895 gen loss 0.39674970507621765
# disc loss 1.3339512348175049 gen loss 0.4148677587509155
# #========== evaluating for epoch 282 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2912 , 0.0020085 , 0.013469 , 0.8202
# # ================== Sampling 500 sequences at epoch 282 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2850239276885986 gen loss 0.38473641872406006
# disc loss 1.2942428588867188 gen loss 0.40523454546928406
# #========== evaluating for epoch 284 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29375 , 0.0020552 , 0.015514 , 0.82117
# # ================== Sampling 500 sequences at epoch 284 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.1880340576171875 gen loss 0.39910149574279785
# disc loss 1.3226515054702759 gen loss 0.36711519956588745
# #========== evaluating for epoch 286 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29172 , 0.0020077 , 0.010465 , 0.81568
# # ================== Sampling 500 sequences at epoch 286 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2547802925109863 gen loss 0.36205846071243286
# disc loss 1.24155855178833 gen loss 0.40754812955856323
# #========== evaluating for epoch 288 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29884 , 0.0018411 , 0.020655 , 0.82678
# # ================== Sampling 500 sequences at epoch 288 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.3011932373046875 gen loss 0.3527441620826721
# disc loss 1.2921929359436035 gen loss 0.3711478114128113
# #========== evaluating for epoch 290 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29239 , 0.001897 , 0.01527 , 0.81124
# # ================== Sampling 500 sequences at epoch 290 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.244604229927063 gen loss 0.35534530878067017
# disc loss 1.268042802810669 gen loss 0.3812318742275238
# #========== evaluating for epoch 292 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.29427 , 0.0020487 , 0.015807 , 0.81968
# # ================== Sampling 500 sequences at epoch 292 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2890021800994873 gen loss 0.370037317276001
# disc loss 1.2502427101135254 gen loss 0.35641735792160034
# #========== evaluating for epoch 294 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.2906 , 0.0020537 , 0.012141 , 0.81718
# # ================== Sampling 500 sequences at epoch 294 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2535979747772217 gen loss 0.3788914680480957
# disc loss 1.2911598682403564 gen loss 0.36966222524642944
# #========== evaluating for epoch 296 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.28873 , 0.0019137 , 0.010254 , 0.81163
# # ================== Sampling 500 sequences at epoch 296 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2386138439178467 gen loss 0.3792663812637329
# disc loss 1.2559561729431152 gen loss 0.38405734300613403
# #========== evaluating for epoch 298 ==========#
# >>> MMD | abs(D_Entropy) | abs(D_Distance) | Pearson Corr
# 0.28923 , 0.0022038 , 0.010201 , 0.83108
# # ================== Sampling 500 sequences at epoch 298 ================== #
# The loci with percentage of gap >= 95% in the cleaned MSA:
#  []
# Their percentage gap are:
#  []
# # ====================================================== #
# disc loss 1.2280436754226685 gen loss 0.37051141262054443
